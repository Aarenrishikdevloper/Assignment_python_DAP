# %%
import pandas as pd 
df = pd.read_csv("Weather.csv")  
unique_wind_speed = df['Wind Speed_km/h'].unique()  
print("The unique Wind speed values are") 
print(unique_wind_speed)
# Out:
# The unique Wind speed values are
# [ 4  7  6  9 15 13 20 22 19 24 30 35 39 32 33 26 44 43 48 37 28 17 11  0
#  83 70 57 46 41 52 50 63 54  2]

# %%
import pandas as pd  
df  = pd.read_csv("weather.csv") 
clear = df[df["Weather"] == "Clear"] 
count = len(clear) 
print("The Number of times when the weather is exactly clear", count)
# Out:
# The Number of times when the weather is exactly clear 1326

# %%
import pandas as pd 
df = pd.read_csv("weather.csv")  
wind = df[df["Wind Speed_km/h"] == 4]  
count  = len(wind)  
print("The Number of times when the wind speed was exactly 4km/h",count)
# Out:
# The Number of times when the wind speed was exactly 4km/h 474

# %%
import pandas as pd 
df = pd.read_csv("weather.csv") 
null_counts = df.isnull().sum()  
print(null_counts[null_counts > 0])
# Out:
# Series([], dtype: int64)

# %%
import pandas as pd 
df = pd.read_csv("weather.csv") 
mean_visibility = df['Visibility_km'].mean() 
print("The mean visibility is", mean_visibility,"km")
# Out:
# The mean visibility is 27.664446721311478 km

# %%
import pandas as pd 
df = pd.read_csv("weather.csv")  
std_pressure = df["Press_kPa"].std()   
print("The Standard derivation of pressure is", std_pressure, "kpa")
# Out:
# The Standard derivation of pressure is 0.8440047459486483 kpa

# %%
import pandas as pd  
df  = pd.read_csv("weather.csv")  
var_humidity = df["Rel Hum_%"].var()
print("The variance of Relative humidity is", var_humidity )
# Out:
# The variance of Relative humidity is 286.24855019850196

# %%
import pandas as pd 
df = pd.read_csv("weather.csv")  
snow_df = df[df['Weather']=="Snow"]   
print(snow_df)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
import pandas as pd 
df = pd.read_csv("weather.csv")  
wind_vis_dif = df[(df['Wind Speed_km/h']>24) & (df['Visibility_km']==25)]  
print(wind_vis_dif)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
import pandas as pd 
df  =  pd.read_csv("weather.csv")    
mean_df  = df['Weather'].mean()   
print(mean_df)
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_4988\2923578843.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 df  =  pd.read_csv("weather.csv")
# ----> 3 mean_df  = df['Weather'].mean()
#       4 print(mean_df)
#
# File c:\users\rishi\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py:6529, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
# ...

# %%
import pandas as pd 
df  = pd.read_csv('weather.csv')   
min_max_df = df.groupby('Weather').agg('max', 'min') 
print(min_max_df)
# Out:
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                                      32.8              20.4         99
# Cloudy                                     30.5              22.6         99
# Drizzle                                    18.8              17.7         96
# Drizzle,Fog                                19.9              19.1        100
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                1.2               0.2         95
# Drizzle,Snow,Fog                            1.1               0.6         98
# Fog                                        20.8              19.6        100
# Freezing Drizzle                           -2.3              -3.3         93
# Freezing Drizzle,Fog                       -0.3              -2.3         94
# Freezing Drizzle,Haze                      -5.0              -7.7         83
# ...

# %%
import pandas as pd 
df  = pd.read_csv('weather.csv')  
fog_df = df[df['Weather'] == 'Fog']  
print(fog_df)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
import pandas as pd 
df  = pd.read_csv('weather.csv')    
clear_vis_df = df[(df['Weather'] == 'Clear') | (df['Visibility_km'] > 40)] 
print(clear_vis_df)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
import pandas as pd 
df  = pd.read_csv('weather.csv')    
clear_humid_vis_df = df[(df['Weather']== 'Clear') & (df['Rel Hum_%'] > 50) | (df['Visibility_km'] >40)]  
print(clear_humid_vis_df)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...
